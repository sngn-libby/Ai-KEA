# %% [markdown]
# #Import Libraries

# %%
# %tensorflow_version 2.x

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pathlib

from tensorflow.keras.layers import Dense, Flatten, Conv2D
from tensorflow.keras.layers import MaxPool2D, MaxPool1D
from tensorflow.keras.layers import Dropout, BatchNormalization

from google.colab import drive

print("Module Loaded.")
print("TensorFlow Version :{}".format(tf.__version__))
print("NumPy Version :{}".format(np.__version__))
print("Matplotlib Version :{}".format(plt.matplotlib.__version__))
# Out:
# TensorFlow 2.x selected.
# Module Loaded.
# TensorFlow Version :2.1.0-rc1
# NumPy Version :1.17.4
# Matplotlib Version :3.1.2

# %%
drive.mount('/content/drive')

data_path = pathlib.Path('/content/drive/Shared drives/scsa_2019_b/Project_Ai-KEA/data_resize/furniture')

num = 0
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
class_name = np.array([item.name for item in data_path.glob('*')])
print(class_name)
# Out:
# ['bookshelves' 'fireplace' 'floor lamp' 'chair' 'entertainment center'
#  'dressing table' 'bed' 'curtain' 'sofa' 'table']

# %% [markdown]
# # Prepare Data

# %% [markdown]
# - **Unzip Data**

# %%
import os

cwd = os.getcwd()
print(cwd)

# !unzip /content/drive/Shared\ drives/scsa_2019_b/Project_Ai-KEA/data_resize/furniture.zip -d /content/furniture
# Out:
# /content
# Archive:  /content/drive/Shared drives/scsa_2019_b/Project_Ai-KEA/data_resize/furniture.zip
#    creating: /content/furniture/bed/
#   inflating: /content/furniture/bed/bed (1).jpg
#   inflating: /content/furniture/bed/bed (10).jpg
#   inflating: /content/furniture/bed/bed (100).jpg
#   inflating: /content/furniture/bed/bed (1000).jpg
#   inflating: /content/furniture/bed/bed (1001).jpg
#   inflating: /content/furniture/bed/bed (1002).jpg
#   inflating: /content/furniture/bed/bed (1003).jpg
#   inflating: /content/furniture/bed/bed (1004).jpg
#   inflating: /content/furniture/bed/bed (1005).jpg
#   inflating: /content/furniture/bed/bed (1006).jpg
#   inflating: /content/furniture/bed/bed (1007).jpg
#   inflating: /content/furniture/bed/bed (1008).jpg
#   inflating: /content/furniture/bed/bed (1009).jpg
#   inflating: /content/furniture/bed/bed (101).jpg
#   inflating: /content/furniture/bed/bed (1010).jpg
#   inflating: /content/furniture/bed/bed (1011).jpg
#   inflating: /content/furniture/bed/bed (1012).jpg
#   inflating: /content/furniture/bed/bed (1013).jpg
#   inflating: /content/furniture/bed/bed (1014).jpg
#   inflating: /content/furniture/bed/bed (1015).jpg
#   inflating: /content/furniture/bed/bed (1016).jpg
#   inflating: /content/furniture/bed/bed (1017).jpg
#   inflating: /content/furniture/bed/bed (1018).jpg
#   inflating: /content/furniture/bed/bed (1019).jpg
#   inflating: /content/furniture/bed/bed (102).jpg
#   inflating: /content/furniture/bed/bed (1020).jpg
#   inflating: /content/furniture/bed/bed (1021).jpg
#   inflating: /content/furniture/bed/bed (1022).jpg
#   inflating: /content/furniture/bed/bed (1023).jpg
#   inflating: /content/furniture/bed/bed (1024).jpg
#   inflating: /content/furniture/bed/bed (1025).jpg
#   inflating: /content/furniture/bed/bed (1026).jpg
#   inflating: /content/furniture/bed/bed (1027).jpg
#   inflating: /content/furniture/table/table (766).jpg
#   inflating: /content/furniture/table/table (767).jpg
#   inflating: /content/furniture/table/table (768).jpg
#   inflating: /content/furniture/table/table (769).jpg
#   inflating: /content/furniture/table/table (77).jpg
#   inflating: /content/furniture/table/table (770).jpg
#   inflating: /content/furniture/table/table (771).jpg
#   inflating: /content/furniture/table/table (772).jpg
#   inflating: /content/furniture/table/table (773).jpg
#   inflating: /content/furniture/table/table (774).jpg
#   inflating: /content/furniture/table/table (775).jpg
#   inflating: /content/furniture/table/table (776).jpg
#   inflating: /content/furniture/table/table (777).jpg
#   inflating: /content/furniture/table/table (778).jpg
#   inflating: /content/furniture/table/table (779).jpg
#   inflating: /content/furniture/table/table (78).jpg
#   inflating: /content/furniture/table/table (780).jpg
#   inflating: /content/furniture/table/table (781).jpg
#   inflating: /content/furniture/table/table (782).jpg
#   inflating: /content/furniture/table/table (783).jpg
#   inflating: /content/furniture/table/table (784).jpg
#   inflating: /content/furniture/table/table (785).jpg
#   inflating: /content/furniture/table/table (786).jpg
#   inflating: /content/furniture/table/table (787).jpg
#   inflating: /content/furniture/table/table (788).jpg
#   inflating: /content/furniture/table/table (789).jpg
#   inflating: /content/furniture/table/table (79).jpg
#   inflating: /content/furniture/table/table (790).jpg
#   inflating: /content/furniture/table/table (791).jpg
#   inflating: /content/furniture/table/table (792).jpg
#   inflating: /content/furniture/table/table (793).jpg
#   inflating: /content/furniture/table/table (794).jpg
#   inflating: /content/furniture/table/table (795).jpg
#   inflating: /content/furniture/table/table (796).jpg
#   inflating: /content/furniture/table/table (797).jpg
#   inflating: /content/furniture/table/table (798).jpg
#   inflating: /content/furniture/table/table (799).jpg
#   inflating: /content/furniture/table/table (8).jpg
#   inflating: /content/furniture/table/table (80).jpg
#   inflating: /content/furniture/table/table (800).jpg
#   inflating: /content/furniture/table/table (801).jpg
#   inflating: /content/furniture/table/table (802).jpg
#   inflating: /content/furniture/table/table (803).jpg
#   inflating: /content/furniture/table/table (804).jpg
#   inflating: /content/furniture/table/table (805).jpg
#   inflating: /content/furniture/table/table (806).jpg
#   inflating: /content/furniture/table/table (807).jpg
#   inflating: /content/furniture/table/table (808).jpg
#   inflating: /content/furniture/table/table (809).jpg
#   inflating: /content/furniture/table/table (81).jpg
#   inflating: /content/furniture/table/table (810).jpg
#   inflating: /content/furniture/table/table (811).jpg
#   inflating: /content/furniture/table/table (812).jpg
#   inflating: /content/furniture/table/table (813).jpg
#   inflating: /content/furniture/table/table (814).jpg
#   inflating: /content/furniture/table/table (815).jpg
#   inflating: /content/furniture/table/table (816).jpg
#   inflating: /content/furniture/table/table (817).jpg
#   inflating: /content/furniture/table/table (818).jpg
#   inflating: /content/furniture/table/table (819).jpg
#   inflating: /content/furniture/table/table (82).jpg
#   inflating: /content/furniture/table/table (820).jpg
#   inflating: /content/furniture/table/table (821).jpg
#   inflating: /content/furniture/table/table (822).jpg
#   inflating: /content/furniture/table/table (823).jpg
#   inflating: /content/furniture/table/table (824).jpg
#   inflating: /content/furniture/table/table (825).jpg
#   inflating: /content/furniture/table/table (826).jpg
#   inflating: /content/furniture/table/table (827).jpg
#   inflating: /content/furniture/table/table (828).jpg
#   inflating: /content/furniture/table/table (829).jpg
#   inflating: /content/furniture/table/table (83).jpg
#   inflating: /content/furniture/table/table (830).jpg
#   inflating: /content/furniture/table/table (831).jpg
#   inflating: /content/furniture/table/table (832).jpg
#   inflating: /content/furniture/table/table (833).jpg
#   inflating: /content/furniture/table/table (834).jpg
#   inflating: /content/furniture/table/table (835).jpg
#   inflating: /content/furniture/table/table (836).jpg
#   inflating: /content/furniture/table/table (837).jpg
#   inflating: /content/furniture/table/table (838).jpg
#   inflating: /content/furniture/table/table (839).jpg
#   inflating: /content/furniture/table/table (84).jpg
#   inflating: /content/furniture/table/table (840).jpg
#   inflating: /content/furniture/table/table (841).jpg
#   inflating: /content/furniture/table/table (842).jpg
#   inflating: /content/furniture/table/table (843).jpg
#   inflating: /content/furniture/table/table (844).jpg
#   inflating: /content/furniture/table/table (845).jpg
#   inflating: /content/furniture/table/table (846).jpg
#   inflating: /content/furniture/table/table (847).jpg
#   inflating: /content/furniture/table/table (848).jpg
#   inflating: /content/furniture/table/table (849).jpg
#   inflating: /content/furniture/table/table (85).jpg
#   inflating: /content/furniture/table/table (850).jpg
#   inflating: /content/furniture/table/table (851).jpg
#   inflating: /content/furniture/table/table (852).jpg
#   inflating: /content/furniture/table/table (853).jpg
#   inflating: /content/furniture/table/table (854).jpg
#   inflating: /content/furniture/table/table (855).jpg
#   inflating: /content/furniture/table/table (856).jpg
#   inflating: /content/furniture/table/table (857).jpg
#   inflating: /content/furniture/table/table (858).jpg
#   inflating: /content/furniture/table/table (859).jpg
#   inflating: /content/furniture/table/table (86).jpg
#   inflating: /content/furniture/table/table (860).jpg
#   inflating: /content/furniture/table/table (861).jpg
#   inflating: /content/furniture/table/table (862).jpg
#   inflating: /content/furniture/table/table (863).jpg
#   inflating: /content/furniture/table/table (864).jpg
#   inflating: /content/furniture/table/table (865).jpg
#   inflating: /content/furniture/table/table (866).jpg
#   inflating: /content/furniture/table/table (867).jpg
#   inflating: /content/furniture/table/table (868).jpg
#   inflating: /content/furniture/table/table (869).jpg
#   inflating: /content/furniture/table/table (87).jpg
#   inflating: /content/furniture/table/table (870).jpg
#   inflating: /content/furniture/table/table (871).jpg
#   inflating: /content/furniture/table/table (872).jpg
#   inflating: /content/furniture/table/table (873).jpg
#   inflating: /content/furniture/table/table (874).jpg
#   inflating: /content/furniture/table/table (875).jpg
#   inflating: /content/furniture/table/table (876).jpg
#   inflating: /content/furniture/table/table (877).jpg
#   inflating: /content/furniture/table/table (878).jpg
#   inflating: /content/furniture/table/table (879).jpg
#   inflating: /content/furniture/table/table (88).jpg
#   inflating: /content/furniture/table/table (880).jpg
#   inflating: /content/furniture/table/table (881).jpg
#   inflating: /content/furniture/table/table (882).jpg
#   inflating: /content/furniture/table/table (883).jpg
#   inflating: /content/furniture/table/table (884).jpg
#   inflating: /content/furniture/table/table (885).jpg
#   inflating: /content/furniture/table/table (886).jpg
#   inflating: /content/furniture/table/table (887).jpg
#   inflating: /content/furniture/table/table (888).jpg
#   inflating: /content/furniture/table/table (889).jpg
#   inflating: /content/furniture/table/table (89).jpg
#   inflating: /content/furniture/table/table (890).jpg
#   inflating: /content/furniture/table/table (891).jpg
#   inflating: /content/furniture/table/table (892).jpg
#   inflating: /content/furniture/table/table (893).jpg
#   inflating: /content/furniture/table/table (894).jpg
#   inflating: /content/furniture/table/table (895).jpg
#   inflating: /content/furniture/table/table (896).jpg
#   inflating: /content/furniture/table/table (897).jpg
#   inflating: /content/furniture/table/table (898).jpg
#   inflating: /content/furniture/table/table (899).jpg
#   inflating: /content/furniture/table/table (9).jpg
#   inflating: /content/furniture/table/table (90).jpg
#   inflating: /content/furniture/table/table (900).jpg
#   inflating: /content/furniture/table/table (901).jpg
#   inflating: /content/furniture/table/table (902).jpg
#   inflating: /content/furniture/table/table (903).jpg
#   inflating: /content/furniture/table/table (904).jpg
#   inflating: /content/furniture/table/table (905).jpg
#   inflating: /content/furniture/table/table (906).jpg
#   inflating: /content/furniture/table/table (907).jpg
#   inflating: /content/furniture/table/table (908).jpg
#   inflating: /content/furniture/table/table (909).jpg
#   inflating: /content/furniture/table/table (91).jpg
#   inflating: /content/furniture/table/table (910).jpg
#   inflating: /content/furniture/table/table (911).jpg
#   inflating: /content/furniture/table/table (912).jpg
#   inflating: /content/furniture/table/table (913).jpg
#   inflating: /content/furniture/table/table (914).jpg
#   inflating: /content/furniture/table/table (915).jpg
#   inflating: /content/furniture/table/table (916).jpg
#   inflating: /content/furniture/table/table (917).jpg
#   inflating: /content/furniture/table/table (918).jpg
#   inflating: /content/furniture/table/table (919).jpg
#   inflating: /content/furniture/table/table (92).jpg
#   inflating: /content/furniture/table/table (920).jpg
#   inflating: /content/furniture/table/table (921).jpg
#   inflating: /content/furniture/table/table (922).jpg
#   inflating: /content/furniture/table/table (923).jpg
#   inflating: /content/furniture/table/table (924).jpg
#   inflating: /content/furniture/table/table (925).jpg
#   inflating: /content/furniture/table/table (926).jpg
#   inflating: /content/furniture/table/table (927).jpg
#   inflating: /content/furniture/table/table (928).jpg
#   inflating: /content/furniture/table/table (929).jpg
#   inflating: /content/furniture/table/table (93).jpg
#   inflating: /content/furniture/table/table (930).jpg
#   inflating: /content/furniture/table/table (931).jpg
#   inflating: /content/furniture/table/table (932).jpg
#   inflating: /content/furniture/table/table (933).jpg
#   inflating: /content/furniture/table/table (934).jpg
#   inflating: /content/furniture/table/table (935).jpg
#   inflating: /content/furniture/table/table (936).jpg
#   inflating: /content/furniture/table/table (937).jpg
#   inflating: /content/furniture/table/table (938).jpg
#   inflating: /content/furniture/table/table (939).jpg
#   inflating: /content/furniture/table/table (94).jpg
#   inflating: /content/furniture/table/table (940).jpg
#   inflating: /content/furniture/table/table (941).jpg
#   inflating: /content/furniture/table/table (942).jpg
#   inflating: /content/furniture/table/table (943).jpg
#   inflating: /content/furniture/table/table (944).jpg
#   inflating: /content/furniture/table/table (945).jpg
#   inflating: /content/furniture/table/table (946).jpg
#   inflating: /content/furniture/table/table (947).jpg
#   inflating: /content/furniture/table/table (948).jpg
#   inflating: /content/furniture/table/table (949).jpg
#   inflating: /content/furniture/table/table (95).jpg
#   inflating: /content/furniture/table/table (950).jpg
#   inflating: /content/furniture/table/table (951).jpg
#   inflating: /content/furniture/table/table (952).jpg
#   inflating: /content/furniture/table/table (953).jpg
#   inflating: /content/furniture/table/table (954).jpg
#   inflating: /content/furniture/table/table (955).jpg
#   inflating: /content/furniture/table/table (956).jpg
#   inflating: /content/furniture/table/table (957).jpg
#   inflating: /content/furniture/table/table (958).jpg
#   inflating: /content/furniture/table/table (959).jpg
#   inflating: /content/furniture/table/table (96).jpg
#   inflating: /content/furniture/table/table (960).jpg
#   inflating: /content/furniture/table/table (961).jpg
#   inflating: /content/furniture/table/table (962).jpg
#   inflating: /content/furniture/table/table (963).jpg
#   inflating: /content/furniture/table/table (964).jpg
#   inflating: /content/furniture/table/table (965).jpg
#   inflating: /content/furniture/table/table (966).jpg
#   inflating: /content/furniture/table/table (967).jpg
#   inflating: /content/furniture/table/table (968).jpg
#   inflating: /content/furniture/table/table (969).jpg
#   inflating: /content/furniture/table/table (97).jpg
#   inflating: /content/furniture/table/table (970).jpg
#   inflating: /content/furniture/table/table (971).jpg
#   inflating: /content/furniture/table/table (972).jpg
#   inflating: /content/furniture/table/table (973).jpg
#   inflating: /content/furniture/table/table (974).jpg
#   inflating: /content/furniture/table/table (975).jpg
#   inflating: /content/furniture/table/table (976).jpg
#   inflating: /content/furniture/table/table (977).jpg
#   inflating: /content/furniture/table/table (978).jpg
#   inflating: /content/furniture/table/table (979).jpg
#   inflating: /content/furniture/table/table (98).jpg
#   inflating: /content/furniture/table/table (980).jpg
#   inflating: /content/furniture/table/table (981).jpg
#   inflating: /content/furniture/table/table (982).jpg
#   inflating: /content/furniture/table/table (983).jpg
#   inflating: /content/furniture/table/table (984).jpg
#   inflating: /content/furniture/table/table (985).jpg
#   inflating: /content/furniture/table/table (986).jpg
#   inflating: /content/furniture/table/table (987).jpg
#   inflating: /content/furniture/table/table (988).jpg
#   inflating: /content/furniture/table/table (989).jpg
#   inflating: /content/furniture/table/table (99).jpg
#   inflating: /content/furniture/table/table (990).jpg
#   inflating: /content/furniture/table/table (991).jpg
#   inflating: /content/furniture/table/table (992).jpg
#   inflating: /content/furniture/table/table (993).jpg
#   inflating: /content/furniture/table/table (994).jpg
#   inflating: /content/furniture/table/table (995).jpg
#   inflating: /content/furniture/table/table (996).jpg
#   inflating: /content/furniture/table/table (997).jpg
#   inflating: /content/furniture/table/table (998).jpg
#   inflating: /content/furniture/table/table (999).jpg

# %% [markdown]
# # Resize Image

# %%
# from PIL import Image

# for j in class_name[1:4]:
#     image = pathlib.Path('/content/drive/Shared drives/scsa_2019_b/Project_Ai-KEA/data/furniture/'+j)
#     image = list(image.glob('*.jpg'))
#     for i in range(len(image)):
#         im = Image.open(str(image[i])).convert('RGB')
#         resize_image = im.resize((im.size[0]//2,im.size[1]//2))
#         resize_image.save('/content/drive/Shared drives/scsa_2019_b/Project_Ai-KEA/data_resize/furniture/{0}/{1}{2:03d}.jpg'.format(j,j,i))
#         print(j, i)

# %%
data_path = pathlib.Path('/content/drive/Shared drives/scsa_2019_b/Project_Ai-KEA/data_resize/furniture')

# %% [markdown]
# #ImageGenerator

# %%
img_size = 112
batch_n = 200

data_path = pathlib.Path('/content/furniture')

# %%
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(
                                #width_shift_range=0.3,
                                #height_shift_range=0.3,
                                #horizontal_flip=True, 
                                #vertical_flip=True,
                                #rotation_range=30,
                                #zoom_range=0.1,
                                #brightness_range=[0.8,1.2],
                                validation_split=0.2,
                                rescale=1./255)

# %%
train_data_generate = image_generator.flow_from_directory(
                        directory=str(data_path),
                        batch_size=batch_n,
                        shuffle=True,
                        target_size=(img_size, img_size),
                        classes = list(class_name),
                        subset='training')
test_data_generate = image_generator.flow_from_directory(
                        directory=str(data_path),
                        batch_size=batch_n,
                        shuffle=True,
                        target_size=(img_size, img_size),
                        classes = list(class_name),
                        subset='validation')
# Out:
# Found 12559 images belonging to 10 classes.
# Found 3135 images belonging to 10 classes.

# %% [markdown]
# # Load Prev Model

# %%
save_path = '/content/drive/Shared drives/scsa_2019_b/Project_Ai-KEA/code/model_checkpoint/'

# %%
# date, epoch, model_name, num
# save_model('day02', epoch=epoch_n, model_name=model_name, num='sey01')

def save_model(date, epoch, model_name, num):
    ai_kea.save(save_path+"aikea_{}_{}_{}_{}.hdf5".format(date, epoch, model_name, num))

# %%
def load_aikea(date, epoch, model_name, num):
  model = tf.keras.models.load_model(save_path+"aikea_{}_{}_{}_{}.hdf5".format(date, epoch, model_name, num))
  return model

# %%
prev_ai_kea = load_aikea('day02', epoch=epoch_n, model_name=model_name, num='sey01')

# %% [markdown]
# #Load VGG

# %% [markdown]
# import model

# %%
import tensorflow.keras.applications.vgg16 as vgg16

model_imported = vgg16.VGG16(
    weights="imagenet", 
    include_top=False,    # dense layer 이 후는 제외
    input_tensor=tf.keras.layers.Input(shape=(img_size, img_size, 3))
    #input_tensor=keras.layers.Input(shape=(49, 49, 3))
)

model_imported.summary()

# %% [markdown]
# ##fine tuning

# %% [markdown]
# freeze layers

# %%
# slicing which layers not to train
for layer in model_imported.layers[:] :
  layer.trainable = False

for layer in model_imported.layers :
  print(layer, layer.trainable)

# %% [markdown]
# make ai-kea model

# %%
ai_kea = tf.keras.models.Sequential()

# conv 0
ai_kea.add(tf.keras.layers.Conv2D(64,3,padding='same',activation='relu',input_shape=(112,112,3))) 
# ai_kea.add(tf.keras.layers.BatchNormalization(momentum=0.85))             # BN
ai_kea.add(tf.keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)))
ai_kea.add(tf.keras.layers.Dropout(0.2))             # BN

# conv 2
ai_kea.add(tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu'))
# ai_kea.add(tf.keras.layers.BatchNormalization(momentum=0.85))             # BN
ai_kea.add(tf.keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)))
ai_kea.add(tf.keras.layers.Dropout(0.2)) 

# conv 3
ai_kea.add(tf.keras.layers.Conv2D(256, 3, padding='same', activation='relu')) 
#ai_kea.add(tf.keras.layers.BatchNormalization(momentum=0.85))             # BN
ai_kea.add(tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)))
ai_kea.add(tf.keras.layers.Dropout(0.2))             # BN

# conv 4
ai_kea.add(tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu')) 
#ai_kea.add(tf.keras.layers.BatchNormalization(momentum=0.85))             # BN
ai_kea.add(tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)))
ai_kea.add(tf.keras.layers.Dropout(0.2))             # BN

ai_kea.add(tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu')) 
#ai_kea.add(tf.keras.layers.BatchNormalization(momentum=0.85))             # BN
ai_kea.add(tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)))
ai_kea.add(tf.keras.layers.Dropout(0.2))             # BN

# dense layers
ai_kea.add(tf.keras.layers.Flatten(name='flatten'))
#ai_kea.add(tf.keras.layers.Dense(1024, activation='relu'))
#ai_kea.add(tf.keras.layers.BatchNormalization(momentum=0.85))            # BN
ai_kea.add(tf.keras.layers.Dense(len(class_name), activation='softmax', name='dense_10'))

ai_kea.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 112, 112, 64)      1792
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 256)       295168
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 13, 13, 256)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 13, 13, 256)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 13, 13, 128)       295040
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 6, 6, 64)          73792
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 742,218
# Trainable params: 742,218
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #model compile & train

# %%
model_name = 'vgg16' # 불러온 모델 이름
date = 'day01'
epoch_n = 50

# %%
def lr_schedule(epoch):
    lr = 1e-2
    if epoch/epoch_n > 0.7:
        lr *= 0.5e-3
    elif epoch/epoch_n > 0.6:
        lr *= 1e-3
    elif epoch/epoch_n > 0.5:
        lr *= 1e-2
    elif epoch/epoch_n > 0.4:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

opt = tf.keras.optimizers.Adam(learning_rate=lr_schedule(0))
lrate = LearningRateScheduler(lr_schedule)
callbacks_list = [lrate]
# Out:
# Learning rate:  0.01

# %%
ai_kea.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
history = ai_kea.fit_generator(
    train_data_generate,
    epochs = epoch_n,
    validation_data = test_data_generate,
    #callbacks=callbacks_list
)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 63 steps, validate for 16 steps
# Epoch 1/100
# 63/63 [==============================] - 24s 386ms/step - loss: 2.1806 - accuracy: 0.2091 - val_loss: 2.0898 - val_accuracy: 0.2788
# Epoch 2/100
# 63/63 [==============================] - 23s 361ms/step - loss: 1.8594 - accuracy: 0.3418 - val_loss: 1.8967 - val_accuracy: 0.3652
# Epoch 3/100
# 63/63 [==============================] - 23s 367ms/step - loss: 1.5822 - accuracy: 0.4584 - val_loss: 1.5834 - val_accuracy: 0.4788
# Epoch 4/100
# 63/63 [==============================] - 23s 369ms/step - loss: 1.3569 - accuracy: 0.5391 - val_loss: 1.3882 - val_accuracy: 0.5640
# Epoch 5/100
# 63/63 [==============================] - 23s 364ms/step - loss: 1.1852 - accuracy: 0.6031 - val_loss: 1.2265 - val_accuracy: 0.6089
# Epoch 6/100
# 63/63 [==============================] - 23s 368ms/step - loss: 1.0441 - accuracy: 0.6510 - val_loss: 1.1206 - val_accuracy: 0.6459
# Epoch 7/100
# 63/63 [==============================] - 23s 366ms/step - loss: 0.9355 - accuracy: 0.6909 - val_loss: 1.1095 - val_accuracy: 0.6443
# Epoch 8/100
# 63/63 [==============================] - 23s 362ms/step - loss: 0.8466 - accuracy: 0.7205 - val_loss: 1.0426 - val_accuracy: 0.6520
# Epoch 9/100
# Epoch 90/100
# 63/63 [==============================] - 23s 362ms/step - loss: 0.0688 - accuracy: 0.9760 - val_loss: 1.2715 - val_accuracy: 0.7573
# Epoch 91/100
# 63/63 [==============================] - 23s 363ms/step - loss: 0.0718 - accuracy: 0.9756 - val_loss: 1.3494 - val_accuracy: 0.7525
# Epoch 92/100
# 63/63 [==============================] - 23s 361ms/step - loss: 0.0875 - accuracy: 0.9690 - val_loss: 1.2603 - val_accuracy: 0.7569
# Epoch 93/100
# 63/63 [==============================] - 22s 357ms/step - loss: 0.0693 - accuracy: 0.9771 - val_loss: 1.2536 - val_accuracy: 0.7643
# Epoch 94/100
# 63/63 [==============================] - 22s 357ms/step - loss: 0.0876 - accuracy: 0.9700 - val_loss: 1.3443 - val_accuracy: 0.7391
# Epoch 95/100
# 63/63 [==============================] - 23s 358ms/step - loss: 0.0701 - accuracy: 0.9761 - val_loss: 1.1450 - val_accuracy: 0.7684
# Epoch 96/100
# 63/63 [==============================] - 24s 378ms/step - loss: 0.0731 - accuracy: 0.9771 - val_loss: 1.2055 - val_accuracy: 0.7576
# Epoch 97/100
# 63/63 [==============================] - 24s 375ms/step - loss: 0.0647 - accuracy: 0.9789 - val_loss: 1.3240 - val_accuracy: 0.7611
# Epoch 98/100
# 63/63 [==============================] - 24s 378ms/step - loss: 0.0597 - accuracy: 0.9794 - val_loss: 1.3061 - val_accuracy: 0.7541
# Epoch 99/100
# 63/63 [==============================] - 24s 378ms/step - loss: 0.0721 - accuracy: 0.9756 - val_loss: 1.2153 - val_accuracy: 0.7499
# Epoch 100/100
# 63/63 [==============================] - 24s 377ms/step - loss: 0.0651 - accuracy: 0.9792 - val_loss: 1.3654 - val_accuracy: 0.7506

# %% [markdown]
# # Save Model

# %%
# %%time

# date, epoch, model_name, num
num += 1
save_model(date, epoch=epoch_n, model_name=model_name, num)
# Out:
# CPU times: user 123 ms, sys: 64.6 ms, total: 187 ms
# Wall time: 379 ms

# %% [markdown]
# # Plot Learning Status

# %%
loss = history.history['loss']
epochs = range(1, len(loss)+1)

plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.title('Validation Loss')
plt.semilogy(epochs, history.history['val_loss'], 'b', label='CNN')
plt.grid(True)
plt.xlabel('Epoch')
plt.ylabel('Loss')
#plt.ylim([0.0, 0.6])
plt.legend(loc='best')

plt.subplot(2, 1, 2)
plt.title('Validation Accuray')
plt.semilogy(epochs, history.history['val_accuracy'], 'b', label='CNN')
plt.grid(True)
plt.ylabel('Accuracy')
plt.ylim([0.5, 0.9])
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-96cdef0a13c4> in <module>()
# ----> 1 loss = history.history['loss']
#       2 epochs = range(1, len(loss)+1)
#       3
#       4 plt.figure(figsize=(10, 10))
#       5 plt.subplot(2, 1, 1)
#
# NameError: name 'history' is not defined

# %%
print(np.max(history.history['val_accuracy']))
# Out:
# 0.2388708

# %% [markdown]
# # CAM

# %%
img_path = '/content/furniture/table/table1'

# %%
import cv2
from keras.applications.vgg16 import decode_predictions


def buildCAM(img_path, img_alpha, heatmap_alpha): # 0<= alpha <=1

    # load the image with the required shape
    img = image.load_img(img_path, target_size=(224, 224))
    # check image
    plt.imshow(img)
    # convert the image to an array
    img = image.img_to_array(img)         # tf.keras.processing
    # expand dimensions so that it represents a single 'sample'
    img = np.expand_dims(img, axis=0)     # numpy
    # prepare the image (e.g. scale pixel values for the vgg)
    img = vgg16.preprocess_input(img)     # VGG16.preprocess_input


    grad_model = tf.keras.models.Model(
      [ai_kea.inputs],                           # input: vgg16 inputs
      [ai_kea.get_layer('block5_conv3').output,  # outputs: vgg16 last conv
      ai_kea.output]                            # softmax out
    )


    # GradientTape 설정
    with tf.GradientTape() as tape:
        conv_outputs, predict = grad_model(img)   # feature, predict
        class_out = predict[:, np.argmax(predict[0])]    # class     

    # feature map
    output = conv_outputs[0]

    # Get gradient for input image
    grads = tape.gradient(class_out, conv_outputs)[0]

    # check grads' shape
    grads.shape, output.shape

    # Average gradients spatially
    weights = tf.reduce_mean(grads, axis=(0, 1))


    # Build a map of filters according to gradients importance
    cam = np.ones(output.shape[0:2], dtype=np.float32)

    for index, w in enumerate(weights):
        cam += w * output[:, :, index]

    # check cam shape
    cam.shape, weights.shape


    # image read: ndarray type
    img = cv2.imread(img_path)
    # GBR -> RGB
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # cv2는 기본적으로 image를 GBR로 처리

    plt.imshow(img)

    img.shape, type(img)


    # resize cam
    cam = cv2.resize(cam.numpy(), (img.shape[1], img.shape[0]))
    cam = np.maximum(cam, 0)          # 0 이상의 값만 취함
    # heatmap : minmax normalized one
    heatmap = (cam - cam.min()) / (cam.max() - cam.min())

    # convert heatmap to rgb
    heatmap = np.uint8(255 * heatmap)                       # RGB range (0~255)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)  # apply color map
    heatmap = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)      # colormap to RGB

    # get heatmap outline
    heatlist = heatmap.tolist()
    t_pos = []
    for i in range(len(heatlist)):
      for j in range(len(heatlist[i])):
        if heatlist[i][j][2]<125: t_pos.append((i, j))

    y_max = max([i[0] for i in t_pos])
    y_min = min([i[0] for i in t_pos])
    x_max = max([i[1] for i in t_pos])
    x_min = min([i[1] for i in t_pos])


    # check heatmap shape
    plt.imshow(heatmap)
    heatmap.shape #(426, 640, 3)

    # blending heatmap: image: 100%, heatmap: 50%
    output_image = cv2.addWeighted(img.astype('uint8'), img_alpha,  # 1: 100%
                                  heatmap, heatmap_alpha,            # 0.5: 50%
                                  0)
    return output_image, y_min, x_min, y_max-y_min, x_max-x_min

# %% [markdown]
# ### Plot Output Image

# %%
# define Model
output_image, yy, xx, h, w = buildCAM(img_path, 1, 0)

# import matplotlib.patches as patches
# fig, ax = plt.subplots(1)
rect = pathces.Rectangle((xx, yy), w, h, linewidth=1, edgecolor='r', facecolor='none')
# ax.add_patch(rect)
# ax.imshow(output_image)
# plot blended image
plt.text(xx, yy, '{}-{}%'.format(decode_predictions(preds, top=2)[0][0][1], decode_predictions(preds, top=2)[0][0][0]))
plt.add_patch(rect)
plt.imshow(output_image)
plt.axis('off')
plt.title(decode_predictions(preds, top=2)[0][0][1])
