# %% [markdown]
# #Import Libraries

# %%
# %tensorflow_version 2.x

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pathlib

from tensorflow.keras.layers import Dense, Flatten, Conv2D
from tensorflow.keras.layers import MaxPool2D, MaxPool1D
from tensorflow.keras.layers import Dropout, BatchNormalization

from google.colab import drive

print("Module Loaded.")
print("TensorFlow Version :{}".format(tf.__version__))
print("NumPy Version :{}".format(np.__version__))
print("Matplotlib Version :{}".format(plt.matplotlib.__version__))
# Out:
# TensorFlow 2.x selected.
# Module Loaded.
# TensorFlow Version :2.1.0-rc1
# NumPy Version :1.17.4
# Matplotlib Version :3.1.2

# %%
drive.mount('/content/drive')

data_path = pathlib.Path('/content/drive/Shared drives/scsa_2019_b/Project_Ai-KEA/data_resize/furniture')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class_name = np.array([item.name for item in data_path.glob('*')])
print(class_name)
# Out:
# ['bookshelves' 'fireplace' 'floor lamp' 'chair' 'entertainment center'
#  'dressing table' 'bed' 'curtain' 'sofa' 'table']

# %% [markdown]
# # Prepare Data

# %% [markdown]
# - **Unzip Data**

# %%
import os

cwd = os.getcwd()
print(cwd)

# !unzip /content/drive/Shared\ drives/scsa_2019_b/Project_Ai-KEA/data_resize/furniture.zip -d /content/furniture
# Out:
# /content
# Archive:  /content/drive/Shared drives/scsa_2019_b/Project_Ai-KEA/data_resize/furniture.zip
# replace /content/furniture/bed/bed (1).jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace /content/furniture/bed/bed (10).jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# # Resize Image

# %%
# from PIL import Image

# for j in class_name[1:4]:
#     image = pathlib.Path('/content/drive/Shared drives/scsa_2019_b/Project_Ai-KEA/data/furniture/'+j)
#     image = list(image.glob('*.jpg'))
#     for i in range(len(image)):
#         im = Image.open(str(image[i])).convert('RGB')
#         resize_image = im.resize((im.size[0]//2,im.size[1]//2))
#         resize_image.save('/content/drive/Shared drives/scsa_2019_b/Project_Ai-KEA/data_resize/furniture/{0}/{1}{2:03d}.jpg'.format(j,j,i))
#         print(j, i)

# %%
# data_path = pathlib.Path('/content/drive/Shared drives/scsa_2019_b/Project_Ai-KEA/data_resize/furniture')

# %% [markdown]
# #ImageGenerator

# %%
img_size = 112
batch_n = 256

data_path = pathlib.Path('/content/furniture')

# %%
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(
                                width_shift_range=0.3,
                                height_shift_range=0.3,
                                horizontal_flip=True, 
                                #vertical_flip=True,
                                #rotation_range=30,
                                zoom_range=0.1,
                                brightness_range=[0.8,1.2],
                                validation_split=0.2,
                                rescale=1./255)

# %%
train_data_generate = image_generator.flow_from_directory(
                        directory=str(data_path),
                        batch_size=batch_n,
                        shuffle=True,
                        target_size=(img_size, img_size),
                        classes = list(class_name),
                        subset='training')
test_data_generate = image_generator.flow_from_directory(
                        directory=str(data_path),
                        batch_size=batch_n,
                        shuffle=True,
                        target_size=(img_size, img_size),
                        classes = list(class_name),
                        subset='validation')
# Out:
# Found 12559 images belonging to 10 classes.
# Found 3135 images belonging to 10 classes.

# %% [markdown]
# # Load Prev Model

# %%
save_path = '/content/drive/Shared drives/scsa_2019_b/Project_Ai-KEA/code/model_checkpoint/'

# %%
# date, epoch, model_name, num
# save_model('day02', epoch=epoch_n, model_name=model_name, num='sey01')

def save_model(date, epoch, model_name, num):
    ai_kea.save(save_path+"aikea_{}_{}_{}_{}.hdf5".format(date, epoch, model_name, num))

# %%
def load_aikea(date, epoch, model_name, num):
  model = tf.keras.models.load_model(save_path+"aikea_{}_{}_{}_{}.hdf5".format(date, epoch, model_name, num))
  return model

# %%
# prev_aikea = load_aikea('day01', epoch=epoch_n, model_name=model_name, num='sey01')

# %% [markdown]
# #Load VGG

# %% [markdown]
# import model

# %%
import tensorflow.keras.applications.vgg16 as vgg16

model_imported = vgg16.VGG16(
    weights="imagenet", 
    include_top=False,    # dense layer 이 후는 제외
    input_tensor=tf.keras.layers.Input(shape=(img_size, img_size, 3))
    #input_tensor=keras.layers.Input(shape=(49, 49, 3))
)

model_imported.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 112, 112, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 112, 112, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 112, 112, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 56, 56, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 56, 56, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 56, 56, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 28, 28, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 28, 28, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 28, 28, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 28, 28, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 14, 14, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 14, 14, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 7, 7, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 7, 7, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 7, 7, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 3, 3, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##fine tuning

# %% [markdown]
# freeze layers

# %%
# slicing which layers not to train
for layer in model_imported.layers[:-4] :
  layer.trainable = False

for layer in model_imported.layers :
  print(layer, layer.trainable)
# Out:
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fe6100fe780> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fe69884f6d8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fe6a71fa7f0> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fe60e8f9780> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fe6108de828> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fe6105deb70> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fe6105dedd8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fe6105e25c0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fe6105eb908> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fe6105ebba8> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fe6105f2fd0> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fe6105f7e10> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fe6105f7eb8> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fe6105fdfd0> False
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fe610601c88> False
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fe610601278> True
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fe610609d68> True
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fe610609d30> True
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fe610614d68> True

# %% [markdown]
# make ai-kea model

# %%
ai_kea = tf.keras.models.Sequential()

ai_kea.add(model_imported)

# Here add new layers
ai_kea.add(Flatten())
# ai_kea.add(Dense(1024, activation='relu'))
# model_fine.add(keras.layers.Dropout(0.5))
#model_fine.add(keras.layers.LeakyReLU(alpha=0.1))
# ai_kea.add(BatchNormalization())   # 필히 사용할 것
ai_kea.add(Dense(10, activation='softmax'))
ai_kea.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 3, 3, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                46090
# =================================================================
# Total params: 14,760,778
# Trainable params: 7,125,514
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %% [markdown]
# #model compile & train

# %%
model_name = 'vgg16' # 불러온 모델 이름
date = 'day02'
epoch_n = 100

# %%
def lr_schedule(epoch):
    lr = 1e-2
    if epoch/epoch_n > 0.8:
        lr *= 0.5e-3
    elif epoch/epoch_n > 0.6:
        lr *= 1e-3
    elif epoch/epoch_n > 0.4:
        lr *= 1e-2
    elif epoch/epoch_n > 0.2:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

opt = tf.keras.optimizers.Adam(learning_rate=lr_schedule(0))
lrate = LearningRateScheduler(lr_schedule)
callbacks_list = [lrate]
# Out:
# Learning rate:  0.01

# %%
ai_kea.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
history = ai_kea.fit_generator(
    train_data_generate,
    epochs = epoch_n,
    validation_data = test_data_generate
)
# Out:
# WARNING:tensorflow:From <ipython-input-25-d48d5c4ba539>:4: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 50 steps, validate for 13 steps
# Epoch 1/100
# 50/50 [==============================] - 97s 2s/step - loss: 2.2424 - accuracy: 0.2130 - val_loss: 1.9930 - val_accuracy: 0.2852
# Epoch 2/100
# 50/50 [==============================] - 92s 2s/step - loss: 1.7463 - accuracy: 0.3750 - val_loss: 1.5147 - val_accuracy: 0.4517
# Epoch 3/100
# 50/50 [==============================] - 91s 2s/step - loss: 1.3004 - accuracy: 0.5363 - val_loss: 1.3365 - val_accuracy: 0.5340
# Epoch 4/100
# 50/50 [==============================] - 91s 2s/step - loss: 1.1087 - accuracy: 0.6157 - val_loss: 1.2309 - val_accuracy: 0.5892
# Epoch 5/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.9543 - accuracy: 0.6729 - val_loss: 1.0942 - val_accuracy: 0.6367
# Epoch 6/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.7823 - accuracy: 0.7344 - val_loss: 0.9606 - val_accuracy: 0.6890
# Epoch 7/100
# 50/50 [==============================] - 90s 2s/step - loss: 0.6788 - accuracy: 0.7724 - val_loss: 0.9017 - val_accuracy: 0.7148
# Epoch 8/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.5893 - accuracy: 0.8111 - val_loss: 0.8849 - val_accuracy: 0.7279
# Epoch 9/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.5477 - accuracy: 0.8248 - val_loss: 0.8521 - val_accuracy: 0.7397
# Epoch 10/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.4693 - accuracy: 0.8504 - val_loss: 0.8587 - val_accuracy: 0.7604
# Epoch 11/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.4441 - accuracy: 0.8568 - val_loss: 0.7614 - val_accuracy: 0.7710
# Epoch 12/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.3975 - accuracy: 0.8733 - val_loss: 0.7914 - val_accuracy: 0.7675
# Epoch 13/100
# 50/50 [==============================] - 90s 2s/step - loss: 0.3796 - accuracy: 0.8770 - val_loss: 0.7756 - val_accuracy: 0.7780
# Epoch 14/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.3487 - accuracy: 0.8912 - val_loss: 0.7355 - val_accuracy: 0.7876
# Epoch 15/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.3394 - accuracy: 0.8904 - val_loss: 0.7187 - val_accuracy: 0.7885
# Epoch 16/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.3211 - accuracy: 0.8966 - val_loss: 0.7740 - val_accuracy: 0.7949
# Epoch 17/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.2823 - accuracy: 0.9082 - val_loss: 0.7844 - val_accuracy: 0.7879
# Epoch 18/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.2801 - accuracy: 0.9078 - val_loss: 0.7749 - val_accuracy: 0.7901
# Epoch 19/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.2602 - accuracy: 0.9154 - val_loss: 0.7699 - val_accuracy: 0.8029
# Epoch 20/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.2522 - accuracy: 0.9188 - val_loss: 0.7667 - val_accuracy: 0.7984
# Epoch 21/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.2301 - accuracy: 0.9266 - val_loss: 0.7740 - val_accuracy: 0.7914
# Epoch 22/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.2330 - accuracy: 0.9224 - val_loss: 0.7853 - val_accuracy: 0.7962
# Epoch 23/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.2055 - accuracy: 0.9341 - val_loss: 0.8480 - val_accuracy: 0.7856
# Epoch 24/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.2158 - accuracy: 0.9304 - val_loss: 0.8142 - val_accuracy: 0.7850
# Epoch 25/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.2194 - accuracy: 0.9272 - val_loss: 0.7794 - val_accuracy: 0.7914
# Epoch 26/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.1878 - accuracy: 0.9385 - val_loss: 0.8707 - val_accuracy: 0.7866
# Epoch 27/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.1813 - accuracy: 0.9396 - val_loss: 0.8618 - val_accuracy: 0.7939
# Epoch 28/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.1780 - accuracy: 0.9396 - val_loss: 0.8325 - val_accuracy: 0.8067
# Epoch 29/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.1644 - accuracy: 0.9449 - val_loss: 0.8574 - val_accuracy: 0.8061
# Epoch 30/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.1604 - accuracy: 0.9466 - val_loss: 0.8946 - val_accuracy: 0.7962
# Epoch 31/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.1603 - accuracy: 0.9470 - val_loss: 0.8592 - val_accuracy: 0.7987
# Epoch 32/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.1352 - accuracy: 0.9543 - val_loss: 0.8602 - val_accuracy: 0.8003
# Epoch 33/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.1374 - accuracy: 0.9537 - val_loss: 0.9186 - val_accuracy: 0.7990
# Epoch 34/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.1325 - accuracy: 0.9573 - val_loss: 0.9478 - val_accuracy: 0.7930
# Epoch 35/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.1245 - accuracy: 0.9608 - val_loss: 0.8961 - val_accuracy: 0.7984
# Epoch 36/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.1280 - accuracy: 0.9583 - val_loss: 0.9609 - val_accuracy: 0.8003
# Epoch 37/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.1172 - accuracy: 0.9604 - val_loss: 0.8701 - val_accuracy: 0.7987
# Epoch 38/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.1122 - accuracy: 0.9630 - val_loss: 0.9252 - val_accuracy: 0.8006
# Epoch 39/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.1193 - accuracy: 0.9606 - val_loss: 0.9109 - val_accuracy: 0.7981
# Epoch 40/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.1199 - accuracy: 0.9607 - val_loss: 0.9458 - val_accuracy: 0.7907
# Epoch 41/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.1046 - accuracy: 0.9642 - val_loss: 0.9974 - val_accuracy: 0.7955
# Epoch 42/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.1183 - accuracy: 0.9602 - val_loss: 1.0797 - val_accuracy: 0.7914
# Epoch 43/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.1142 - accuracy: 0.9641 - val_loss: 0.9353 - val_accuracy: 0.8006
# Epoch 44/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.1022 - accuracy: 0.9672 - val_loss: 1.0515 - val_accuracy: 0.7923
# Epoch 45/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.1103 - accuracy: 0.9643 - val_loss: 0.9880 - val_accuracy: 0.7959
# Epoch 46/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.1042 - accuracy: 0.9652 - val_loss: 1.0387 - val_accuracy: 0.7974
# Epoch 47/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0890 - accuracy: 0.9686 - val_loss: 1.0903 - val_accuracy: 0.7997
# Epoch 48/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.1079 - accuracy: 0.9646 - val_loss: 1.0625 - val_accuracy: 0.7971
# Epoch 49/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.1226 - accuracy: 0.9600 - val_loss: 1.0735 - val_accuracy: 0.7974
# Epoch 50/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.1024 - accuracy: 0.9665 - val_loss: 0.9927 - val_accuracy: 0.8048
# Epoch 51/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.1010 - accuracy: 0.9662 - val_loss: 1.1014 - val_accuracy: 0.8019
# Epoch 52/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0948 - accuracy: 0.9681 - val_loss: 1.1105 - val_accuracy: 0.7793
# Epoch 53/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0868 - accuracy: 0.9721 - val_loss: 1.1118 - val_accuracy: 0.7907
# Epoch 54/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0778 - accuracy: 0.9748 - val_loss: 0.9993 - val_accuracy: 0.8064
# Epoch 55/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0814 - accuracy: 0.9744 - val_loss: 1.0632 - val_accuracy: 0.8080
# Epoch 56/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0806 - accuracy: 0.9733 - val_loss: 1.0822 - val_accuracy: 0.8035
# Epoch 57/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.1178 - accuracy: 0.9678 - val_loss: 1.0278 - val_accuracy: 0.8022
# Epoch 58/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0814 - accuracy: 0.9748 - val_loss: 1.1975 - val_accuracy: 0.7837
# Epoch 59/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0993 - accuracy: 0.9685 - val_loss: 1.1401 - val_accuracy: 0.7917
# Epoch 60/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0899 - accuracy: 0.9721 - val_loss: 1.0919 - val_accuracy: 0.7965
# Epoch 61/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0701 - accuracy: 0.9765 - val_loss: 1.1477 - val_accuracy: 0.8000
# Epoch 62/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0756 - accuracy: 0.9762 - val_loss: 1.1741 - val_accuracy: 0.8019
# Epoch 63/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0827 - accuracy: 0.9728 - val_loss: 1.1216 - val_accuracy: 0.8077
# Epoch 64/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0804 - accuracy: 0.9754 - val_loss: 1.1265 - val_accuracy: 0.7920
# Epoch 65/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0893 - accuracy: 0.9728 - val_loss: 1.0734 - val_accuracy: 0.8077
# Epoch 66/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0878 - accuracy: 0.9721 - val_loss: 1.0992 - val_accuracy: 0.8099
# Epoch 67/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0662 - accuracy: 0.9808 - val_loss: 1.1364 - val_accuracy: 0.8057
# Epoch 68/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0762 - accuracy: 0.9752 - val_loss: 1.0252 - val_accuracy: 0.7959
# Epoch 69/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0714 - accuracy: 0.9787 - val_loss: 1.2649 - val_accuracy: 0.8000
# Epoch 70/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0676 - accuracy: 0.9779 - val_loss: 1.2295 - val_accuracy: 0.7978
# Epoch 71/100
# 50/50 [==============================] - 90s 2s/step - loss: 0.0680 - accuracy: 0.9803 - val_loss: 1.3051 - val_accuracy: 0.7981
# Epoch 72/100
# 50/50 [==============================] - 90s 2s/step - loss: 0.0613 - accuracy: 0.9807 - val_loss: 1.2560 - val_accuracy: 0.8080
# Epoch 73/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0520 - accuracy: 0.9829 - val_loss: 1.2150 - val_accuracy: 0.8038
# Epoch 74/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0597 - accuracy: 0.9809 - val_loss: 1.4611 - val_accuracy: 0.7789
# Epoch 75/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0636 - accuracy: 0.9798 - val_loss: 1.2314 - val_accuracy: 0.8019
# Epoch 76/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0719 - accuracy: 0.9764 - val_loss: 1.4392 - val_accuracy: 0.7946
# Epoch 77/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0651 - accuracy: 0.9798 - val_loss: 1.3432 - val_accuracy: 0.8045
# Epoch 78/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0592 - accuracy: 0.9818 - val_loss: 1.1604 - val_accuracy: 0.8134
# Epoch 79/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0702 - accuracy: 0.9775 - val_loss: 1.1727 - val_accuracy: 0.7962
# Epoch 80/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0699 - accuracy: 0.9771 - val_loss: 1.4038 - val_accuracy: 0.7936
# Epoch 81/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0547 - accuracy: 0.9818 - val_loss: 1.2396 - val_accuracy: 0.8029
# Epoch 82/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0686 - accuracy: 0.9790 - val_loss: 1.2866 - val_accuracy: 0.8070
# Epoch 83/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0724 - accuracy: 0.9781 - val_loss: 1.2741 - val_accuracy: 0.7955
# Epoch 84/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0682 - accuracy: 0.9799 - val_loss: 1.2131 - val_accuracy: 0.8048
# Epoch 85/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0424 - accuracy: 0.9866 - val_loss: 1.2792 - val_accuracy: 0.8102
# Epoch 86/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0649 - accuracy: 0.9801 - val_loss: 1.2706 - val_accuracy: 0.7984
# Epoch 87/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0588 - accuracy: 0.9815 - val_loss: 1.3953 - val_accuracy: 0.7898
# Epoch 88/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0573 - accuracy: 0.9803 - val_loss: 1.2511 - val_accuracy: 0.8131
# Epoch 89/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0528 - accuracy: 0.9833 - val_loss: 1.4689 - val_accuracy: 0.7907
# Epoch 90/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0767 - accuracy: 0.9793 - val_loss: 1.3280 - val_accuracy: 0.7971
# Epoch 91/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0656 - accuracy: 0.9799 - val_loss: 1.2854 - val_accuracy: 0.7872
# Epoch 92/100
# 50/50 [==============================] - 91s 2s/step - loss: 0.0580 - accuracy: 0.9821 - val_loss: 1.2407 - val_accuracy: 0.8032
# Epoch 93/100
# 50/50 [==============================] - 92s 2s/step - loss: 0.0625 - accuracy: 0.9831 - val_loss: 1.2249 - val_accuracy: 0.8061
# Epoch 94/100
# 50/50 [==============================] - 93s 2s/step - loss: 0.0504 - accuracy: 0.9835 - val_loss: 1.4619 - val_accuracy: 0.7994
# Epoch 95/100
# 34/50 [===================>..........] - ETA: 23s - loss: 0.0571 - accuracy: 0.9827

# %% [markdown]
# # Save Model

# %%
# %%time

# date, epoch, model_name, num
save_model(date, epoch=epoch_n, model_name=model_name, 'sey01')

# %% [markdown]
# # Plot Learning Status

# %%
loss = history.history['loss']
epochs = range(1, len(loss)+1)

plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.title('Validation Loss')
plt.semilogy(epochs, history.history['val_loss'], 'b', label='CNN')
plt.grid(True)
plt.xlabel('Epoch')
plt.ylabel('Loss')
#plt.ylim([0.0, 0.6])
plt.legend(loc='best')

plt.subplot(2, 1, 2)
plt.title('Validation Accuray')
plt.semilogy(epochs, history.history['val_accuracy'], 'b', label='CNN')
plt.grid(True)
plt.ylabel('Accuracy')
plt.ylim([0.5, 0.9])
plt.legend(loc='best')
plt.show()

# %%
print(np.max(history.history['val_accuracy']))

# %% [markdown]
# > ### CAM

# %% [markdown]
# - make Model Function

# %%
import cv2
import matplotlib.patches as patches
from keras.applications.vgg16 import decode_predictions
from tensorflow.keras.preprocessing import image


def buildCAM(img_path, img_alpha, heatmap_alpha): # 0<= alpha <=1

    # load the image with the required shape
    img = image.load_img(img_path, target_size=(img_size, img_size))
    # check image
    plt.imshow(img)
    # convert the image to an array
    img = image.img_to_array(img)         # tf.keras.processing
    # expand dimensions so that it represents a single 'sample'
    img = np.expand_dims(img, axis=0)     # numpy
    # prepare the image (e.g. scale pixel values for the vgg)
    img = vgg16.preprocess_input(img)     # VGG16.preprocess_input

    grad_model = tf.keras.models.Model(
        [ai_kea.inputs],                           # input: vgg16 inputs
        [ai_kea.get_layer('conv_feat').output,  # outputs: vgg16 last conv
        ai_kea.output]                           # softmax out
    )

    # GradientTape 설정
    with tf.GradientTape() as tape:
        conv_outputs, predict = grad_model(img)   # feature, predict
        class_out = predict[:, np.argmax(predict[0])]    # class     
    print(predict[0])

    # feature map
    output = conv_outputs[0]

    # Get gradient for input image
    grads = tape.gradient(class_out, conv_outputs)[0]

    # check grads' shape
    print('grads', grads.shape, output.shape)

    # Average gradients spatially
    weights = tf.reduce_mean(grads, axis=(0, 1))

    
    # Build a map of filters according to gradients importance
    cam = np.ones(output.shape[0:2], dtype=np.float32)

    for index, w in enumerate(weights):
        print(w)
        cam += w * output[:, :, index]

    # check cam shape
    print('cam', cam.shape, weights.shape)
    print(cam)


    # image read: ndarray type
    img = cv2.imread(img_path)
    # GBR -> RGB
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # cv2는 기본적으로 image를 GBR로 처리

    plt.imshow(img)

    print('img', img.shape, type(img))


    # resize cam
    cam = cv2.resize(cam.numpy(), (img.shape[1], img.shape[0]))
    cam = np.maximum(cam, 0)          # 0 이상의 값만 취함
    # heatmap : minmax normalized one
    heatmap = (cam - cam.min()) / (cam.max() - cam.min())

    # convert heatmap to rgb
    heatmap = np.uint8(255 * heatmap)                       # RGB range (0~255)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)  # apply color map
    heatmap = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)      # colormap to RGB
    
    # get heatmap outline
    heatlist = heatmap.tolist()
    t_pos = []
    for i in range(len(heatlist)):
      for j in range(len(heatlist[i])):
        if heatlist[i][j][2]<200: t_pos.append((i, j))

    y_max = max([i[0] for i in t_pos])
    y_min = min([i[0] for i in t_pos])
    x_max = max([i[1] for i in t_pos])
    x_min = min([i[1] for i in t_pos])

    # check heatmap shape
    plt.imshow(heatmap)
    heatmap.shape #(426, 640, 3)

    # blending heatmap: image: 100%, heatmap: 50%
    output_image = cv2.addWeighted(img.astype('uint8'), img_alpha,  # 1: 100%
                                  heatmap, heatmap_alpha,            # 0.5: 50%
                                  0)
    
    
    return predict[0], output_image, y_min, x_min, (y_max-y_min), (x_max-x_min)

# %%
img_path = '/content/furniture/table/table1'

# %%
import cv2
import matplotlib.patches as patches
from keras.applications.vgg16 import decode_predictions
from tensorflow.keras.preprocessing import image

# define Model
pred_list=[]
pred_list, output_image, yy, xx, h, w = buildCAM(img_path, 1, 0)
pred_cls = class_name[np.argmax(pred_list)]
print(pred_cls)
fig, ax = plt.subplots(1)
rect = patches.Rectangle((xx, yy), w, h, linewidth=1, edgecolor='r', facecolor='none')
ax.add_patch(rect)

rect_txt = patches.Rectangle((xx,yy), 80, 20, edgecolor='r', facecolor='r')
ax.add_patch(rect)
ax.add_patch(rect_txt)
ax.text(xx+10, yy+15, 
         '{}'.format(pred_cls),
         fontsize=18, color='w')
ax.imshow(output_image)
