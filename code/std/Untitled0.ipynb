# %% [markdown]
# #Fold

# %%
from PIL import Image 


img = Image.open('/content/sdfsdf/IMG_7596.JPG').convert('RGB')
print(type(img))
img.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-11fee6b5aee9> in <module>()
#       2
#       3
# ----> 4 img = Image.open('/content/sdfsdf/IMG_7596.JPG').convert('RGB')
#       5 print(type(img))
#       6 img.show()
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2528
#    2529     if filename:
# -> 2530         fp = builtins.open(filename, "rb")
#    2531         exclusive_fp = True
#    2532
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/sdfsdf/IMG_7596.JPG'

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# load the image with the required shape
img = image.load_img('/content/sdfsdf/IMG_7596.JPG')
# check image

plt.imshow(img)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-3a1daa67cc30> in <module>()
#       3
#       4 # load the image with the required shape
# ----> 5 img = image.load_img('/content/sdfsdf/IMG_7596.JPG')
#       6 # check image
#       7
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
# ...

# %%
plt.imshow(img)

# %%
import numpy as np

a = np.ndarray(shape=(3,3), dtype=float, order='F')
print(a)
a[0:2, 0:2] = np.ndarray(shape=(2,2), dtype=float, order='F')
print(a)

for i in range(1, 4, 2): 
  for j in range(1, 4, 2):
      b = a[i:i+2, j:j+2].rehsap()
      print(b)
# Out:
# [[4.04254077e-316 2.16443571e-312 2.31297541e-312]
#  [6.79038653e-313 2.29175545e-312 1.23075756e-312]
#  [2.16443571e-312 2.33419537e-312 2.29315642e+188]]
# [[2.04945703e-316 5.45690684e-316 2.31297541e-312]
#  [0.00000000e+000 0.00000000e+000 1.23075756e-312]
#  [2.16443571e-312 2.33419537e-312 2.29315642e+188]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-2c5868efa3bc> in <module>()
#       8 for i in range(1, 4, 2):
#       9   for j in range(1, 4, 2):
# ---> 10       b = a[i:i+2, j:j+2].rehsap()
#      11       print(b)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'rehsap'

# %% [markdown]
# #dddd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/Shared drives/scsa_2019_b/Project_Ai-KEA/code/module

import plotGraph as pg
# Out:
# /content/drive/Shared drives/scsa_2019_b/Project_Ai-KEA/code/module

# %%
f = open('/content/drive/Shared drives/scsa_2019_b/Project_Ai-KEA/doc/plot txt/seyNet.txt', 'r')
lines = f.read()

# %%
pg.plotHistoryGraph(lines, 100)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
